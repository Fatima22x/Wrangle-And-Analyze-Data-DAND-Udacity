# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ### The following visualisations and insights are taken from data from the WeRateDogs Twitter account displayed here:

# %%
from IPython.display import Image
Image(filename='Account.png')

# %%
twitter_archive_master = pd.read_csv('twitter_archive_master.csv')

# %%
twitter_archive_master.head()
# Out:
#              tweet_id                  timestamp              source  \
# 0  892420643555336193  2017-08-01 16:23:56+00:00  Twitter for iPhone
# 1  666029285002620928  2015-11-15 23:05:30+00:00  Twitter for iPhone
# 2  666033412701032449  2015-11-15 23:21:54+00:00  Twitter for iPhone
# 3  666044226329800704  2015-11-16 00:04:52+00:00  Twitter for iPhone
# 4  666049248165822465  2015-11-16 00:24:50+00:00  Twitter for iPhone
#
#                                                 text  \
# 0  This is Phineas. He's a mystical boy. Only eve...
# 1  This is a western brown Mitsubishi terrier. Up...
# 2  Here is a very happy pup. Big fan of well-main...
# 3  This is a purebred Piers Morgan. Loves to Netf...
# 4  Here we have a 1949 1st generation vulpix. Enj...
#
#                                        expanded_urls  rating_numerator  \
# 0  https://twitter.com/dog_rates/status/892420643...                13
# 1  https://twitter.com/dog_rates/status/666029285...                 7
# ...

# %%
twitter_archive_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1986 entries, 0 to 1985
# Data columns (total 22 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            1986 non-null   int64
#  1   timestamp           1986 non-null   object
#  2   source              1986 non-null   object
#  3   text                1986 non-null   object
#  4   expanded_urls       1986 non-null   object
#  5   rating_numerator    1986 non-null   int64
#  6   rating_denominator  1986 non-null   int64
#  7   name                1986 non-null   object
#  8   dog_stage           1986 non-null   object
#  9   favorite_count      1986 non-null   int64
#  10  retweet_count       1986 non-null   int64
#  11  created_at          1986 non-null   object
#  12  jpg_url             1986 non-null   object
#  13  p1                  1986 non-null   object
#  14  p1_conf             1986 non-null   float64
# ...

# %% [markdown]
# ### Visualization 1: Dog stages

# %%
twitter_archive_master.dog_stage.value_counts().plot(kind='pie', autopct='%1.1f%%', figsize=(10,10))

# %% [markdown]
# - Most of dog stage values are not documented and therefore classified as None, whilst 10% of dogs are in the pupper stage. (Pupper means a small doggo, usually younger!)
# - Least dog stage is fluffer with under 1%. (Fluffer is a term commonly given to dogs with seemingly excess fur!)

# %% [markdown]
# ### Visualization 2: Source of tweets

# %%
twitter_archive_master.source.hist(figsize=(10,10))

# %% [markdown]
# - Most popular source of tweeting was by using Twitter for iPhone, Twitter Web Client and Tweetdeck were rarely used for tweeting in the WeRateDogs account.

# %% [markdown]
# ### Visualization 3: Correlation between retweets and favorites

# %%
ax = twitter_archive_master.plot.scatter(x='retweet_count', y='favorite_count', c='DarkBlue')
ax.set_xlabel("Retweet Count")
ax.set_ylabel("Favorite Count")
# Out:
# Text(0, 0.5, 'Favorite Count')

# %% [markdown]
# - There's a positive correlation between retweet and favourites count, but then again there usually is when it comes to twitter.

# %% [markdown]
# ### Conclusion

# %% [markdown]
# The WeRateDogs account is full of information, however we must first wrangle the data by gathering, assessing then cleaning to get the most out of it!
